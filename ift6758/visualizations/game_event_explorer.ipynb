# %%
from ift6758.visualizations.rink_plot_widget import interactive_explorer
import importlib

# %%
# Launch the interactive explorer for the 2017 regular season
interactive_explorer(2017, "reg")

# %%
from ift6758.visualizations.rink_plot_widget import interactive_explorer

# %%
interactive_explorer(2017, "playoffs")

# %%
interactive_explorer(2018, "reg")
