# %% [markdown]
# # Data fetching - NHL Play-by-Play
#
# This notebook shows how to fetch the data using the API and data fetching code

# %%
from ift6758.data import SeasonData

# %%
# Collect data for the 2016-2017 season
season2016 = SeasonData(2016)
season2016.get_data_from_api()

# %%
# Collect data for the 2017-2018 season
season2017 = SeasonData(2017)
season2017.get_data_from_api()

# %%
# Collect data for the 2018-2019 season
season2018 = SeasonData(2018)
season2018.get_data_from_api()

# %%
# Collect data for the 2019-2020 season
season2019 = SeasonData(2019)
season2019.get_data_from_api()

# %%
# Collect data for the 2020-2021 season
season2020 = SeasonData(2020)
season2020.get_data_from_api()

# %%
# Collect data for the 2021-2022 season
season2021 = SeasonData(2021)
season2021.get_data_from_api()

# %%
# Collect data for the 2022-2023 season
season2022 = SeasonData(2022)
season2022.get_data_from_api()

# %%
# Collect data for the 2023-2024 season
season2023 = SeasonData(2023)
season2023.get_data_from_api()
